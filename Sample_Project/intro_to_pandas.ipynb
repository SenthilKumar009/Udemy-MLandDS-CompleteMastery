# %%
import pandas as pd

# %%
# 2 main DataTypes
series = pd.Series(['BMW', 'AUDI', 'Merceds-BenZ'])
series
# Out:
# 0             BMW
# 1            AUDI
# 2    Merceds-BenZ
# dtype: object

# %%
# Series is a one dimensional data type

# %%
colours = pd.Series(['Red', 'Green', 'Black', 'Yellow'])
colours
# Out:
# 0       Red
# 1     Green
# 2     Black
# 3    Yellow
# dtype: object

# %%
# DataFrame is a Two dimensional data type

# %%
car_data = pd.DataFrame({"Car": series, "Color": colours})
car_data
# Out:
#             Car   Color
# 0           BMW     Red
# 1          AUDI   Green
# 2  Merceds-BenZ   Black
# 3           NaN  Yellow

# %%
car_sales = pd.read_csv('car_data.csv')
car_sales.head(15)
# Out:
#             Make   Color  Odometer  Doors      Price
# 0            BMW   Black     15000    NaN    $12,000
# 1           Audi   White      6000    NaN    $15,000
# 2           BenZ  Maroon      7000    4.0    $33,000
# 3    Rolls Royce   White     12000    2.0  $1,45,000
# 4        Porsche     Red     25000    2.0  $1,35,000
# 5    Lamborghini     Red     12000    2.0    $90,000
# 6         Jaguar   Black     18000    4.0    $60,000
# 7      Landrover   Black      9000    4.0  $1,35,000
# 8       Meserati   Black     12000    2.0  $1,20,500
# 9        Bentley  Yellow     15000    4.0  $1,20,500
# 10  Aston Martin   White     18000    4.0  $1,20,500
# 11           BMW   White      9000    2.0  $1,20,500

# %%
#Exporting a DataFrame
car_sales.to_csv("exported_car_sales_data.csv", index=False)

# %%
exported_data = pd.read_csv('exported_car_sales_data.csv')
exported_data
# Out:
#             Make   Color  Odometer  Doors      Price
# 0            BMW   Black     15000      4    $12,000
# 1           Audi   White      6000      4    $15,000
# 2           BenZ  Maroon     12000      4    $33,000
# 3    Rolls Royce   White      9000      2  $1,45,000
# 4        Porsche     Red      6000      2  $1,35,000
# 5    Lamborghini     Red     12000      2    $90,000
# 6         Jaguar   Black     18000      4    $60,000
# 7      Landrover   Green      9000      4  $1,35,000
# 8       Meserati   Black     12000      2  $1,20,500
# 9        Bentley  Yellow     15000      4  $2,22,000
# 10  Aston Martin   White     18000      4  $2,10,000
# 11           BMW   White      9000      2    $50,000

# %% [markdown]
# # Describing Data

# %%
car_sales.describe
# Out:
# <bound method NDFrame.describe of             Make   Color  Odometer  Doors      Price
# 0            BMW   Black     15000      4    $12,000
# 1           Audi   White      6000      4    $15,000
# 2           BenZ  Maroon     12000      4    $33,000
# 3    Rolls Royce   White      9000      2  $1,45,000
# 4        Porsche     Red      6000      2  $1,35,000
# 5    Lamborghini     Red     12000      2    $90,000
# 6         Jaguar   Black     18000      4    $60,000
# 7      Landrover   Green      9000      4  $1,35,000
# 8       Meserati   Black     12000      2  $1,20,500
# 9        Bentley  Yellow     15000      4  $2,22,000
# 10  Aston Martin   White     18000      4  $2,10,000
# 11           BMW   White      9000      2    $50,000>

# %%
car_sales.dtypes
# Out:
# Make        object
# Color       object
# Odometer     int64
# Doors        int64
# Price       object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Color', 'Odometer', 'Doors', 'Price'], dtype='object')

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      12 non-null     object
#  1   Color     12 non-null     object
#  2   Odometer  12 non-null     int64
#  3   Doors     12 non-null     int64
#  4   Price     12 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 608.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer    11750.000000
# Doors           3.166667
# dtype: float64

# %%
car_prices = pd.Series([3000, 4000, 5000])
car_prices.mean()
# Out:
# 4000.0

# %%
car_sales.sum()
# Out:
# Make        BMWAudiBenZRolls RoycePorscheLamborghiniJaguar...
# Color       BlackWhiteMaroonWhiteRedRedBlackGreenBlackYell...
# Odometer                                               141000
# Doors                                                      38
# Price       $12,000$15,000$33,000$1,45,000$1,35,000$90,000...
# dtype: object

# %% [markdown]
# # Selecting and Viewing data

# %%
car_sales.head()
# Out:
#           Make   Color  Odometer  Doors      Price
# 0          BMW   Black     15000      4    $12,000
# 1         Audi   White      6000      4    $15,000
# 2         BenZ  Maroon     12000      4    $33,000
# 3  Rolls Royce   White      9000      2  $1,45,000
# 4      Porsche     Red      6000      2  $1,35,000

# %%
car_sales.tail()
# Out:
#             Make   Color  Odometer  Doors      Price
# 7      Landrover   Green      9000      4  $1,35,000
# 8       Meserati   Black     12000      2  $1,20,500
# 9        Bentley  Yellow     15000      4  $2,22,000
# 10  Aston Martin   White     18000      4  $2,10,000
# 11           BMW   White      9000      2    $50,000

# %%
animal = pd.Series(['Cat', 'Dog', 'Monkey', 'Pig', 'Panda'], index=[0,3,6,9,3])
animal
# Out:
# 0       Cat
# 3       Dog
# 6    Monkey
# 9       Pig
# 3     Panda
# dtype: object

# %%
# loc --> loc refer the index value
animal.loc[3]
# Out:
# 3      Dog
# 3    Panda
# dtype: object

# %%
# iloc --> iloc refers to the position value.
animal.iloc[3]
# Out:
# 'Pig'

# %%
car_sales['Color']
# Out:
# 0      Black
# 1      White
# 2     Maroon
# 3      White
# 4        Red
# 5        Red
# 6      Black
# 7      Green
# 8      Black
# 9     Yellow
# 10     White
# 11     White
# Name: Color, dtype: object

# %%
car_sales[['Make', 'Color']].head()
# Out:
#           Make   Color
# 0          BMW   Black
# 1         Audi   White
# 2         BenZ  Maroon
# 3  Rolls Royce   White
# 4      Porsche     Red

# %%
car_sales[car_sales["Make"]=='BMW']
# Out:
#    Make  Color  Odometer  Doors    Price
# 0   BMW  Black     15000      4  $12,000
# 11  BMW  White      9000      2  $50,000

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors         2  4
# Make
# Aston Martin  0  1
# Audi          0  1
# BMW           1  1
# BenZ          0  1
# Bentley       0  1
# Jaguar        0  1
# Lamborghini   1  0
# Landrover     0  1
# Meserati      1  0
# Porsche       1  0
# Rolls Royce   1  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#               Odometer  Doors
# Make
# Aston Martin     18000      4
# Audi              6000      4
# BMW              12000      3
# BenZ             12000      4
# Bentley          15000      4
# Jaguar           18000      4
# Lamborghini      12000      2
# Landrover         9000      4
# Meserati         12000      2
# Porsche           6000      2
# Rolls Royce       9000      2

# %%
import matplotlib as mt

# %%
car_sales['Odometer'].plot()

# %%
car_sales['Odometer'].hist()

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\.\,]', '').astype(int)
print(car_sales['Price'])
# Out:
# 0      12000
# 1      15000
# 2      33000
# 3     145000
# 4     135000
# 5      90000
# 6      60000
# 7     135000
# 8     120500
# 9     222000
# 10    210000
# 11     50000
# Name: Price, dtype: int64

# %%
car_sales['Price'].plot()

# %%
car_data_missing = pd.read_csv('car_data.csv')
car_data_missing
# Out:
#             Make   Color  Odometer  Doors      Price
# 0            BMW   Black   15000.0    NaN    $12,000
# 1           Audi   White    6000.0    NaN    $15,000
# 2           BenZ  Maroon       NaN    4.0    $33,000
# 3    Rolls Royce   White       NaN    2.0  $1,45,000
# 4        Porsche     Red       NaN    2.0  $1,35,000
# 5    Lamborghini     Red   12000.0    2.0    $90,000
# 6         Jaguar   Black   18000.0    4.0    $60,000
# 7      Landrover     NaN    9000.0    4.0  $1,35,000
# 8       Meserati     NaN   12000.0    2.0  $1,20,500
# 9        Bentley  Yellow   15000.0    4.0        NaN
# 10  Aston Martin   White   18000.0    4.0        NaN
# 11           BMW   White    9000.0    2.0        NaN

# %%
## update value in NaN fields
car_data_missing['Odometer'].fillna(car_data_missing['Odometer'].mean())
# Out:
# 0     15000.000000
# 1      6000.000000
# 2     12666.666667
# 3     12666.666667
# 4     12666.666667
# 5     12000.000000
# 6     18000.000000
# 7      9000.000000
# 8     12000.000000
# 9     15000.000000
# 10    18000.000000
# 11     9000.000000
# Name: Odometer, dtype: float64

# %%
car_data_missing
# Out:
#             Make   Color      Odometer  Doors      Price
# 0            BMW   Black  15000.000000    NaN    $12,000
# 1           Audi   White   6000.000000    NaN    $15,000
# 2           BenZ  Maroon  12666.666667    4.0    $33,000
# 3    Rolls Royce   White  12666.666667    2.0  $1,45,000
# 4        Porsche     Red  12666.666667    2.0  $1,35,000
# 5    Lamborghini     Red  12000.000000    2.0    $90,000
# 6         Jaguar   Black  18000.000000    4.0    $60,000
# 7      Landrover     NaN   9000.000000    4.0  $1,35,000
# 8       Meserati     NaN  12000.000000    2.0  $1,20,500
# 9        Bentley  Yellow  15000.000000    4.0        NaN
# 10  Aston Martin   White  18000.000000    4.0        NaN
# 11           BMW   White   9000.000000    2.0        NaN

# %%
car_data_missing['Odometer'].fillna(car_data_missing['Odometer'].mean(), inplace=True)

# %%
## Drop the NaN columns...
car_data_missing.dropna(inplace=True)

# %%
car_data_missing.to_csv('car_data_drop_data.csv')

# %%
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price
# 0            BMW   Black     15000    NaN    $12,000
# 1           Audi   White      6000    NaN    $15,000
# 2           BenZ  Maroon      7000    4.0    $33,000
# 3    Rolls Royce   White     12000    2.0  $1,45,000
# 4        Porsche     Red     25000    2.0  $1,35,000
# 5    Lamborghini     Red     12000    2.0    $90,000
# 6         Jaguar   Black     18000    4.0    $60,000
# 7      Landrover   Black      9000    4.0  $1,35,000
# 8       Meserati   Black     12000    2.0  $1,20,500
# 9        Bentley  Yellow     15000    4.0  $1,20,500
# 10  Aston Martin   White     18000    4.0  $1,20,500
# 11           BMW   White      9000    2.0  $1,20,500

# %%
## column from Series
seats_column = pd.Series([5,5,5,5,5])

# new column to the dataframe
car_sales['Seats'] = seats_column
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price  Seats
# 0            BMW   Black     15000    NaN    $12,000    5.0
# 1           Audi   White      6000    NaN    $15,000    5.0
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0
# 5    Lamborghini     Red     12000    2.0    $90,000    NaN
# 6         Jaguar   Black     18000    4.0    $60,000    NaN
# 7      Landrover   Black      9000    4.0  $1,35,000    NaN
# 8       Meserati   Black     12000    2.0  $1,20,500    NaN
# 9        Bentley  Yellow     15000    4.0  $1,20,500    NaN
# 10  Aston Martin   White     18000    4.0  $1,20,500    NaN
# 11           BMW   White      9000    2.0  $1,20,500    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)

# %%
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price  Seats
# 0            BMW   Black     15000    NaN    $12,000    5.0
# 1           Audi   White      6000    NaN    $15,000    5.0
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0
# 5    Lamborghini     Red     12000    2.0    $90,000    5.0
# 6         Jaguar   Black     18000    4.0    $60,000    5.0
# 7      Landrover   Black      9000    4.0  $1,35,000    5.0
# 8       Meserati   Black     12000    2.0  $1,20,500    5.0
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0
# 10  Aston Martin   White     18000    4.0  $1,20,500    5.0
# 11           BMW   White      9000    2.0  $1,20,500    5.0

# %%
### column from Python list
fuel_mileage = [12.5, 7.5, 6.7, 9.0, 6,7,8,9,10,11,12, 6.8]
car_sales['Mileage'] = fuel_mileage
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price  Seats  Mileage
# 0            BMW   Black     15000    NaN    $12,000    5.0     12.5
# 1           Audi   White      6000    NaN    $15,000    5.0      7.5
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0      9.0
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 5    Lamborghini     Red     12000    2.0    $90,000    5.0      7.0
# 6         Jaguar   Black     18000    4.0    $60,000    5.0      8.0
# 7      Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 8       Meserati   Black     12000    2.0  $1,20,500    5.0     10.0
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 10  Aston Martin   White     18000    4.0  $1,20,500    5.0     12.0
# 11           BMW   White      9000    2.0  $1,20,500    5.0      6.8

# %%
car_sales['Total_Fuel_Used'] = car_sales['Odometer'] / car_sales['Mileage']
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price  Seats  Mileage  \
# 0            BMW   Black     15000    NaN    $12,000    5.0     12.5
# 1           Audi   White      6000    NaN    $15,000    5.0      7.5
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0      9.0
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 5    Lamborghini     Red     12000    2.0    $90,000    5.0      7.0
# 6         Jaguar   Black     18000    4.0    $60,000    5.0      8.0
# 7      Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 8       Meserati   Black     12000    2.0  $1,20,500    5.0     10.0
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 10  Aston Martin   White     18000    4.0  $1,20,500    5.0     12.0
# 11           BMW   White      9000    2.0  $1,20,500    5.0      6.8
#
#     Total_Fuel_Used
# 0       1200.000000
# 1        800.000000
# ...

# %%
car_sales['Total Wheels'] = 4

# %%
car_sales
# Out:
#             Make   Color  Odometer  Doors      Price  Seats  Mileage  \
# 0            BMW   Black     15000    NaN    $12,000    5.0     12.5
# 1           Audi   White      6000    NaN    $15,000    5.0      7.5
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0      9.0
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 5    Lamborghini     Red     12000    2.0    $90,000    5.0      7.0
# 6         Jaguar   Black     18000    4.0    $60,000    5.0      8.0
# 7      Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 8       Meserati   Black     12000    2.0  $1,20,500    5.0     10.0
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 10  Aston Martin   White     18000    4.0  $1,20,500    5.0     12.0
# 11           BMW   White      9000    2.0  $1,20,500    5.0      6.8
#
#     Total_Fuel_Used  Total Wheels
# 0       1200.000000             4
# ...

# %%
# Shuffle the data frame
car_sales.sample(frac=0.5)
# Out:
#          Make   Color  Odometer  Doors      Price  Seats  Mileage  \
# 0         BMW   Black     15000    NaN    $12,000    5.0     12.5
# 4     Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 9     Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 11        BMW   White      9000    2.0  $1,20,500    5.0      6.8
# 7   Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 2        BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
#
#     Total_Fuel_Used  Total Wheels
# 0       1200.000000             4
# 4       4166.666667             4
# 9       1363.636364             4
# 11      1323.529412             4
# 7       1000.000000             4
# 2       1044.776119             4

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#             Make   Color  Odometer  Doors      Price  Seats  Mileage  \
# 7      Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 0            BMW   Black     15000    NaN    $12,000    5.0     12.5
# 4        Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 5    Lamborghini     Red     12000    2.0    $90,000    5.0      7.0
# 8       Meserati   Black     12000    2.0  $1,20,500    5.0     10.0
# 6         Jaguar   Black     18000    4.0    $60,000    5.0      8.0
# 3    Rolls Royce   White     12000    2.0  $1,45,000    5.0      9.0
# 11           BMW   White      9000    2.0  $1,20,500    5.0      6.8
# 2           BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 1           Audi   White      6000    NaN    $15,000    5.0      7.5
# 10  Aston Martin   White     18000    4.0  $1,20,500    5.0     12.0
#
#     Total_Fuel_Used  Total Wheels
# 7       1000.000000             4
# ...

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#             Make   Color  Odometer  Doors      Price  Seats  Mileage  \
# 0      Landrover   Black      9000    4.0  $1,35,000    5.0      9.0
# 1            BMW   Black     15000    NaN    $12,000    5.0     12.5
# 2        Porsche     Red     25000    2.0  $1,35,000    5.0      6.0
# 3    Lamborghini     Red     12000    2.0    $90,000    5.0      7.0
# 4       Meserati   Black     12000    2.0  $1,20,500    5.0     10.0
# 5         Jaguar   Black     18000    4.0    $60,000    5.0      8.0
# 6    Rolls Royce   White     12000    2.0  $1,45,000    5.0      9.0
# 7            BMW   White      9000    2.0  $1,20,500    5.0      6.8
# 8           BenZ  Maroon      7000    4.0    $33,000    5.0      6.7
# 9        Bentley  Yellow     15000    4.0  $1,20,500    5.0     11.0
# 10          Audi   White      6000    NaN    $15,000    5.0      7.5
# 11  Aston Martin   White     18000    4.0  $1,20,500    5.0     12.0
#
#     Total_Fuel_Used  Total Wheels
# 0       1000.000000             4
# ...

# %%
car_sales_shuffled
# Out:
#     level_0  index          Make   Color  Odometer  Doors      Price  Seats  \
# 0         0      8      Meserati   Black     12000    2.0  $1,20,500    5.0
# 1         1      7     Landrover   Black      9000    4.0  $1,35,000    5.0
# 2         2     10  Aston Martin   White     18000    4.0  $1,20,500    5.0
# 3         3      6        Jaguar   Black     18000    4.0    $60,000    5.0
# 4         4      3   Rolls Royce   White     12000    2.0  $1,45,000    5.0
# 5         5      9       Bentley  Yellow     15000    4.0  $1,20,500    5.0
# 6         6     11           BMW   White      9000    2.0  $1,20,500    5.0
# 7         7      2          BenZ  Maroon      7000    4.0    $33,000    5.0
# 8         8      1          Audi   White      6000    NaN    $15,000    5.0
# 9         9      0           BMW   Black     15000    NaN    $12,000    5.0
# 10       10      4       Porsche     Red     25000    2.0  $1,35,000    5.0
# ...
